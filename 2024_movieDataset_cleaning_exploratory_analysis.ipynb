# %% [markdown]
# ### Sourced DataSet from Kaggle; https://www.kaggle.com/datasets/parthdande/imdb-dataset-2024-updated/data

# %%
# import libraries needed for data cleaning and exploration
import pandas as pd
#import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Read in data from .csv file
newMovieData = pd.read_csv('IMDb_Dataset_2024.csv')
newMovieData
# Out:
#                                              Title  IMDb Rating  Year  \
# 0                                        Gladiator          8.5  2000
# 1    Mission: Impossible - Dead Reckoning Part One          7.7  2023
# 2             Rebel Moon - Part Two: The Scargiver          5.2  2024
# 3                             Inglourious Basterds          8.4  2009
# 4                                      Borderlands          7.1  2024
# ..                                             ...          ...   ...
# 395                            Mother of the Bride          4.8  2024
# 396                        Beetlejuice Beetlejuice          7.1  2024
# 397                                The Idea of You          6.4  2024
# 398                                             IF          6.7  2024
# 399                                   The Fall Guy          7.1  2024
#
#     Certificates      Genre               Director  \
# 0              R     Action           Ridley Scott
# ...

# %%
# Showcase first 10 data record
newMovieData.head(10)
# Out:
#                                            Title  IMDb Rating  Year  \
# 0                                      Gladiator          8.5  2000
# 1  Mission: Impossible - Dead Reckoning Part One          7.7  2023
# 2           Rebel Moon - Part Two: The Scargiver          5.2  2024
# 3                           Inglourious Basterds          8.4  2009
# 4                                    Borderlands          7.1  2024
# 5                                  Jurassic Park          8.2  1993
# 6                              The Fifth Element          7.6  1997
# 7                                     Inside Out          8.1  2015
# 8                   Descendants: The Rise of Red          7.1  2024
# 9                                           Wish          5.6  2023
#
#   Certificates      Genre               Director  \
# 0            R     Action           Ridley Scott
# 1        PG-13     Action  Christopher McQuarrie
# 2        PG-13     Action            Zack Snyder
# ...

# %%
# showcase number of rows and columns available in this dataset
newMovieData.shape
# Out:
# (400, 9)

# %%
print("Number of Rows :", newMovieData.shape[0])
print("Number of Columns :", newMovieData.shape[1])
# Out:
# Number of Rows : 400
# Number of Columns : 9

# %%
# Summary of dataset and its datatype
newMovieData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Title               400 non-null    object
#  1   IMDb Rating         400 non-null    float64
#  2   Year                400 non-null    int64
#  3   Certificates        400 non-null    object
#  4   Genre               400 non-null    object
#  5   Director            400 non-null    object
#  6   Star Cast           400 non-null    object
#  7   MetaScore           400 non-null    float64
#  8   Duration (minutes)  400 non-null    float64
# dtypes: float64(3), int64(1), object(5)
# memory usage: 28.2+ KB

# %%
#Check for null values within dataset
newMovieData.isnull().sum()
# Out:
# Title                 0
# IMDb Rating           0
# Year                  0
# Certificates          0
# Genre                 0
# Director              0
# Star Cast             0
# MetaScore             0
# Duration (minutes)    0
# dtype: int64

# %% [markdown]
# #### Output shows there are no null values within this dataset. Great!

# %%
# Generate descriptive statistics to ensure there are no abnormality with the numerical entries
newMovieData.describe()
# Out:
#        IMDb Rating         Year   MetaScore  Duration (minutes)
# count   400.000000   400.000000  400.000000          400.000000
# mean      7.110250  2015.150000   66.898750          116.334750
# std       0.932251    13.470194   15.312006           21.369757
# min       3.900000  1939.000000   26.000000           80.000000
# 25%       6.700000  2010.750000   57.750000          101.000000
# 50%       7.100000  2023.000000   66.900000          116.000000
# 75%       7.700000  2024.000000   77.000000          124.000000
# max       9.200000  2025.000000  100.000000          206.000000

# %% [markdown]
# #### All looks good, no negative value or abnormal number in any field

# %%
# Check for duplicate entry
newMovieData.duplicated().any()
# Out:
# True

# %%
#Delete duplicate data entry
newMovieData = newMovieData.drop_duplicates()
newMovieData
# Out:
#                                              Title  IMDb Rating  Year  \
# 0                                        Gladiator          8.5  2000
# 1    Mission: Impossible - Dead Reckoning Part One          7.7  2023
# 2             Rebel Moon - Part Two: The Scargiver          5.2  2024
# 3                             Inglourious Basterds          8.4  2009
# 4                                      Borderlands          7.1  2024
# ..                                             ...          ...   ...
# 391                                 Anyone But You          6.1  2023
# 394                              Kinds of Kindness          7.0  2024
# 395                            Mother of the Bride          4.8  2024
# 397                                The Idea of You          6.4  2024
# 399                                   The Fall Guy          7.1  2024
#
#     Certificates      Genre               Director  \
# 0              R     Action           Ridley Scott
# ...

# %% [markdown]
# ### Data Exploration --

# %%
#find average movie Duration(minutes) and show Titles that are greater than the average
average_duration = newMovieData['Duration (minutes)'].mean()
average_duration
# Out:
# 117.95372549019606

# %%
#Show titles that are greater than the average movie duration
newMovieData[newMovieData['Duration (minutes)']>=120]['Title']
# Out:
# 0                                          Gladiator
# 1      Mission: Impossible - Dead Reckoning Part One
# 2               Rebel Moon - Part Two: The Scargiver
# 3                               Inglourious Basterds
# 5                                      Jurassic Park
#                            ...
# 332                                       Road House
# 373                                    The Holdovers
# 378                 Once Upon a Time... in Hollywood
# 394                                Kinds of Kindness
# 399                                     The Fall Guy
# Name: Title, Length: 83, dtype: object

# %%
# display top 10 lengthy movie
top10_length = newMovieData.nlargest(10, 'Duration (minutes)')[['Title','Duration (minutes)']]\
.set_index('Title')
# .set_index('Title') to ensure Title is used as index
top10_length
# Out:
#                                                    Duration (minutes)
# Title
# Killers of the Flower Moon                                      206.0
# Animal                                                          204.0
# The Green Mile                                                  189.0
# Avengers: Endgame                                               181.0
# The Wolf of Wall Street                                         180.0
# The Lord of the Rings: The Fellowship of the Ring               178.0
# The Batman                                                      176.0
# The Godfather                                                   175.0
# Heat                                                            170.0
# Interstellar                                                    169.0

# %%
# use of barplot to display a more visual representation of above

sns.barplot(x="Duration (minutes)", y=top10_length.index,data=top10_length)
plt.title("Top 10 Lengthy Movies")
plt.show

#y-axis is title, x-axis is duration(minutes)
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# Which year have the highest average rating?
newMovieData.columns
# Out:
# Index(['Title', 'IMDb Rating', 'Year', 'Certificates', 'Genre', 'Director',
#        'Star Cast', 'MetaScore', 'Duration (minutes)'],
#       dtype='object')

# %%
newMovieData.groupby('Year')['IMDb Rating'].mean().sort_values(ascending=False)
# Out:
# Year
# 1972    9.200000
# 1957    9.000000
# 1990    8.700000
# 1991    8.600000
# 2000    8.500000
# 2009    8.350000
# 1994    8.350000
# 2003    8.200000
# 1976    8.200000
# 1939    8.100000
# 1995    8.075000
# 1986    8.000000
# 1987    8.000000
# 1968    8.000000
# 1993    8.000000
# 2006    7.850000
# 2011    7.850000
# 2001    7.800000
# 1971    7.800000
# 2008    7.775000
# 2013    7.760000
# 2015    7.750000
# 2014    7.725000
# 1999    7.700000
# 2007    7.675000
# 1979    7.650000
# 2017    7.600000
# 1981    7.600000
# 2016    7.585714
# 1988    7.500000
# 2002    7.450000
# 1997    7.450000
# 2018    7.371429
# 2021    7.333333
# 2004    7.280000
# 2012    7.200000
# 2010    7.166667
# 1984    7.166667
# 2019    7.122222
# 2005    7.100000
# 2025    7.100000
# 1983    7.000000
# 2023    6.979487
# 1985    6.950000
# 2022    6.946154
# 2024    6.577215
# 1996    6.500000
# Name: IMDb Rating, dtype: float64

# %%
# use of Scatterplot to visualize Ratings by year
sns.scatterplot(x='Year',y='IMDb Rating',data=newMovieData)
plt.title("Movie Ratings by Year")
plt.show()

# %%
# Show Number of movies released each year
newMovieData['Year'].value_counts()
# Out:
# 2024    79
# 2023    39
# 2022    13
# 2019     9
# 2018     7
# 2016     7
# 2001     6
# 2017     6
# 2021     6
# 1999     5
# 2004     5
# 2013     5
# 1995     4
# 2008     4
# 1994     4
# 2014     4
# 2007     4
# 2015     4
# 2005     3
# 2010     3
# 1984     3
# 1997     2
# 1979     2
# 1993     2
# 2009     2
# 2003     2
# 1985     2
# 2006     2
# 2011     2
# 2002     2
# 1990     1
# 1987     1
# 1939     1
# 2025     1
# 1971     1
# 1972     1
# 2000     1
# 1983     1
# 1991     1
# 1957     1
# 1976     1
# 1986     1
# 1981     1
# 1968     1
# 1996     1
# 2012     1
# 1988     1
# Name: Year, dtype: int64

# %%
# Filter for number of movies released each year for the last 10 years
last_ten = newMovieData[newMovieData['Year'] >= 2015]

# %%
# using countplot
sns.countplot(x='Year',data=last_ten)
plt.title("Number of Movies Released Each Year (In Past 10 Years)")
plt.xticks(rotation=45)
plt.show()

# %%
# Show movie titles with highest ratings and its director
topDirectors = newMovieData.nlargest(10, 'IMDb Rating')[['Title','IMDb Rating','Director']]\
.set_index('Title')

topDirectors
# Out:
#                                                    IMDb Rating  \
# Title
# The Godfather                                              9.2
# 12 Angry Men                                               9.0
# The Dark Knight                                            9.0
# The Lord of the Rings: The Fellowship of the Ring          8.9
# Pulp Fiction                                               8.9
# Inception                                                  8.8
# Interstellar                                               8.7
# Goodfellas                                                 8.7
# The Matrix                                                 8.7
# Dune: Part Two                                             8.6
#
#                                                                Director
# Title
# The Godfather                                      Francis Ford Coppola
# 12 Angry Men                                               Sidney Lumet
# ...

# %%
# Check for any recurring director among the top ratings
topDirectors['Director'].value_counts()
# Out:
# Christopher Nolan       3
# Francis Ford Coppola    1
# Sidney Lumet            1
# Peter Jackson           1
# Quentin Tarantino       1
# Martin Scorsese         1
# Lana Wachowski          1
# Denis Villeneuve        1
# Name: Director, dtype: int64

# %%
# Show top movies by Genre
top_Genre = newMovieData.nlargest(10, 'IMDb Rating')[['Genre','Title','IMDb Rating']]\
.set_index('Title')
top_Genre
# Out:
#                                                        Genre  IMDb Rating
# Title
# The Godfather                                          Crime          9.2
# 12 Angry Men                                           Crime          9.0
# The Dark Knight                                       Action          9.0
# The Lord of the Rings: The Fellowship of the Ring     Action          8.9
# Pulp Fiction                                           Crime          8.9
# Inception                                             Action          8.8
# Interstellar                                       Adventure          8.7
# Goodfellas                                         Biography          8.7
# The Matrix                                            Action          8.7
# Dune: Part Two                                        Action          8.6

# %% [markdown]
# #### Create New Column And Classify Movie Ratings [Excellent, Good, Average]

# %%
# Create function to hold if- condition

def rating(rating):
    if rating>=7.0:
        return "Excellent"
    elif rating>=6.0:
        return "Good"
    else:
        return "Average"

# %%
# Apply function defined above, add to dataframe as newMovieData['Rating_class']
newMovieData['Rating_class'] = newMovieData['IMDb Rating'].apply(rating)
# Out:
# /var/folders/_c/xz5426bj64nbnrdrml1lr1mc0000gn/T/ipykernel_59305/1643704721.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   newMovieData['Rating_class'] = newMovieData['IMDb Rating'].apply(rating)

# %%
# Confirm new column 'Rating_class' have been added to dataset
newMovieData.head(5)
# Out:
#                                            Title  IMDb Rating  Year  \
# 0                                      Gladiator          8.5  2000
# 1  Mission: Impossible - Dead Reckoning Part One          7.7  2023
# 2           Rebel Moon - Part Two: The Scargiver          5.2  2024
# 3                           Inglourious Basterds          8.4  2009
# 4                                    Borderlands          7.1  2024
#
#   Certificates      Genre               Director  \
# 0            R     Action           Ridley Scott
# 1        PG-13     Action  Christopher McQuarrie
# 2        PG-13     Action            Zack Snyder
# 3            R  Adventure      Quentin Tarantino
# 4            R     Action               Eli Roth
#
#                                    Star Cast  MetaScore  Duration (minutes)  \
# 0  David FranzoniJohn LoganWilliam Nicholson       67.0               155.0
# 1         Tom CruiseHayley AtwellVing Rhames       81.0               163.0
# ...

# %%
# check for popuar Genre(By count) in entire dataset
newMovieData['Genre'].value_counts()
# Out:
# Action       79
# Animation    50
# Comedy       30
# Adventure    25
# Crime        23
# Horror       21
# Drama        19
# Fantasy       4
# Biography     3
# Thriller      1
# Name: Genre, dtype: int64

# %%
# Top Genres by Rating
newMovieData.groupby('Genre')['IMDb Rating'].mean().sort_values(ascending=False)
# Out:
# Genre
# Crime        7.782609
# Biography    7.466667
# Animation    7.458000
# Adventure    7.400000
# Thriller     7.400000
# Action       7.159494
# Drama        6.952632
# Fantasy      6.850000
# Comedy       6.840000
# Horror       6.295238
# Name: IMDb Rating, dtype: float64

# %%
# barplot for Top Genres
sns.barplot(x='Genre',y='IMDb Rating',data=newMovieData)
plt.title("Top Rated Genres")
plt.xticks(rotation=45)
plt.show()

# %%
newMovieData.to_csv('imdbMovie_explorDataset.csv', index=False)
